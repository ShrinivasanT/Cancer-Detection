# %% [markdown]
# <h1>Cancer Risk Detection</h1>

# %% [markdown]
#  Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
CRD = pd.read_csv('thyroid_cancer_risk_data.csv')
CRD = CRD.drop(columns=['Patient_ID','Country','Ethnicity'])
CRD = CRD.dropna()
CRD.shape
# Out:
# (212691, 14)

# %%
CRD.head()
# Out:
#    Age  Gender Family_History Radiation_Exposure Iodine_Deficiency Smoking  \
# 0   66    Male             No                Yes                No      No
# 1   29    Male             No                Yes                No      No
# 2   86    Male             No                 No                No      No
# 3   75  Female             No                 No                No      No
# 4   35  Female            Yes                Yes                No      No
#
#   Obesity Diabetes  TSH_Level  T3_Level  T4_Level  Nodule_Size  \
# 0      No       No       9.37      1.67      6.16         1.08
# 1      No       No       1.83      1.73     10.54         4.05
# 2      No       No       6.26      2.59     10.57         4.61
# 3      No       No       4.10      2.62     11.04         2.46
# 4      No       No       9.10      2.11     10.71         2.11
#
#   Thyroid_Cancer_Risk Diagnosis
# 0                 Low    Benign
# 1                 Low    Benign
# 2                 Low    Benign
# ...

# %% [markdown]
# Relation between Age and Risk as Bar chart

# %%
# plt.bar(CRD['Age'][:20], CRD['Thyroid_Cancer_Risk'][:20])
# plt.xlabel('Age')
# plt.ylabel('Risk')

# %% [markdown]
# Convert String values to Binary

# %%
label_encoders = {}
for col in CRD.select_dtypes(include=['object']).columns:
  le = LabelEncoder()
  CRD[col] = le.fit_transform(CRD[col])
  label_encoders[col] =le

# %%
x = CRD.drop(columns="Thyroid_Cancer_Risk")
y = CRD['Thyroid_Cancer_Risk']
x.head()
# Out:
#    Age  Gender  Family_History  Radiation_Exposure  Iodine_Deficiency  \
# 0   66       1               0                   1                  0
# 1   29       1               0                   1                  0
# 2   86       1               0                   0                  0
# 3   75       0               0                   0                  0
# 4   35       0               1                   1                  0
#
#    Smoking  Obesity  Diabetes  TSH_Level  T3_Level  T4_Level  Nodule_Size  \
# 0        0        0         0       9.37      1.67      6.16         1.08
# 1        0        0         0       1.83      1.73     10.54         4.05
# 2        0        0         0       6.26      2.59     10.57         4.61
# 3        0        0         0       4.10      2.62     11.04         2.46
# 4        0        0         0       9.10      2.11     10.71         2.11
#
#    Diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
x_train_scaled = scaler.fit_transform(x_train.iloc[:, :5])  # Returns NumPy array
x_test_scaled = scaler.transform(x_test.iloc[:, :5])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
scaler = StandardScaler()
x_train.iloc[:, :5] = x_train_scaled.astype(int)
x_test.iloc[:, :5] = x_test_scaled.astype(int)

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = LR.predict(x_test)
accuracy = accuracy_score(y_pred,y_test)

# %%
print(f"The accuracy of model using Logistic Regression is {accuracy*100}%")
# Out:
# The accuracy of model using Logistic Regression is 53.701309386680464%

# %% [markdown]
# Now Using RandomForest

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train, y_train)

# Predictions
y_pred = model.predict(x_test)

# %%
accuracyRD = accuracy_score(y_pred,y_test)
print(f"The accuracy of model using Random Forest is {accuracyRD*100}%")
# Out:
# The accuracy of model using Random Forest is 50.25741084651732%
